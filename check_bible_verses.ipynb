# %% [markdown]
# ## What do the Bible pickles look like?
#
# Nothing fancy . . . just a notebook to load and display pickled bible verses . . .

# %%
import time, pickle, glob, os
from queue import Queue
from threading import Thread
from matching_functions import *

BIBLE_SHINGLE_FOLDER = '/home/spenteco/text_reuse.HOME/bible_pickles/'

BIBLE_PICKLE_DATA = []
    
for path_to_bible in glob.glob(BIBLE_SHINGLE_FOLDER + '*.pickle'):
    for v in load_pickle_file(path_to_bible):
        
        BIBLE_PICKLE_DATA.append([path_to_bible, v])

# %%
print(len(BIBLE_PICKLE_DATA))
print(BIBLE_PICKLE_DATA[0])
# Out:
# 104374
# ['/home/spenteco/text_reuse.HOME/bible_pickles/KJV_OTA.pickle', {'reference': 'Genesis.1.1', 'tokens': ['In', ' ', 'the', ' ', 'beginning', ' ', 'God', ' ', 'created', ' ', 'the', ' ', 'heaven', ' ', 'and', ' ', 'the', ' ', 'earth', '.'], 'lemmas': [' ', ' ', ' ', ' ', 'beginning', ' ', 'god', ' ', 'create', ' ', ' ', ' ', 'heaven', ' ', ' ', ' ', ' ', ' ', 'earth', ' '], 'non_space_lemmas': ['beginning', 'god', 'create', 'heaven', 'earth'], 'offsets': [4, 6, 8, 12, 18], 'shingles': {('beginning', 'god', 'create'): [[0, 2]], ('god', 'create', 'heaven'): [[1, 3]], ('create', 'heaven', 'earth'): [[2, 4]]}}]

# %%
for v in BIBLE_PICKLE_DATA:
    if 'Song of Solomon' in v[1]['reference'] and 'A10675' in v[0]:
        print(v[0], v[1])
        
print('Done!')
# Out:
# /home/spenteco/text_reuse.HOME/bible_pickles/A10675.pickle {'reference': 'Song of Solomon.1.1', 'tokens': ['1', ' ', 'LEt', ' ', 'hī', ' ', 'kisse', ' ', 'me', ' ', 'with', ' ', 'the', ' ', 'kisses', ' ', 'of', ' ', 'his', ' ', 'mouthe', ':', ' ', 'for', ' ', 'thy', ' ', 'love', ' ', 'is', ' ', 'better', ' ', 'then', ' ', 'wine', '.'], 'lemmas': [' ', ' ', 'let', ' ', 'hī', ' ', 'kiss', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'kiss', ' ', ' ', ' ', ' ', ' ', 'mouth', ' ', ' ', ' ', ' ', ' ', ' ', 'love', ' ', ' ', ' ', 'better', ' ', ' ', ' ', 'wine', ' '], 'non_space_lemmas': ['let', 'hī', 'kiss', 'kiss', 'mouth', 'love', 'better', 'wine'], 'offsets': [2, 4, 6, 14, 20, 27, 31, 35], 'shingles': {('let', 'hī', 'kiss'): [[0, 2]], ('hī', 'kiss', 'kiss'): [[1, 3]], ('kiss', 'kiss', 'mouth'): [[2, 4]], ('kiss', 'mouth', 'love'): [[3, 5]], ('mouth', 'love', 'better'): [[4, 6]], ('love', 'better', 'wine'): [[5, 7]]}}
# ...
